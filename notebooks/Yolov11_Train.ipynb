# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wEY0HugRfdzjbGE1oyzm")
project = rf.workspace("project1-esgu8").project("updated-with-test")
version = project.version(5)
dataset = version.download("yolov11")

# %%
# !pip install ultralytics

# %%
# !sed -i 's|\(train: \).*|\1../train/images|' {dataset.location}/data.yaml
# !sed -i 's|\(val: \).*|\1../valid/images|' {dataset.location}/data.yaml

# %%
from ultralytics import YOLO


# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml batch=6 epochs=50 imgsz=1280 plots=True val=True

# %%
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=yolo11x.pt, data=/content/updated-with-test-5/data.yaml, epochs=50, time=None, patience=100, batch=6, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# Overriding model.yaml nc=80 with nc=4

#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,878,396 parameters, 56,878,380 gradients, 195.5 GFLOPs

# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3321.4±935.9 MB/s, size: 154.4 KB)
# train: Scanning /content/updated-with-test-5/train/labels.cache... 1854 images, 0 backgrounds, 0 corrupt: 100% 1854/1854 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 839.9±493.7 MB/s, size: 159.7 KB)
# val: Scanning /content/updated-with-test-5/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.000515625), 173 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 8 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      23.5G      0.935     0.7603     0.9135        167       1280: 100% 309/309 [01:53<00:00,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  3.52it/s]
#                    all         75       1825      0.589       0.62      0.553      0.371

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      23.8G     0.9428     0.5574     0.9092        196       1280: 100% 309/309 [01:47<00:00,  2.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.54it/s]
#                    all         75       1825      0.874      0.704      0.788      0.528

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      23.7G     0.9842     0.5852     0.9281        270       1280: 100% 309/309 [01:46<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825      0.774       0.73      0.768      0.518

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      23.7G     0.9109     0.5431     0.9097        176       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.38it/s]
#                    all         75       1825      0.855      0.764      0.811      0.543

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      23.9G     0.8948     0.4863     0.8931        243       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.56it/s]
#                    all         75       1825       0.85      0.793      0.834      0.564

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      23.8G     0.8747     0.4627     0.8908        182       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.51it/s]
#                    all         75       1825      0.779      0.779      0.818       0.55

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      23.8G     0.8452     0.4481     0.8829        279       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.47it/s]
#                    all         75       1825       0.91      0.783      0.855       0.61

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      23.7G     0.8408     0.4376     0.8786        199       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.51it/s]
#                    all         75       1825      0.914      0.759      0.842      0.588

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825      0.936      0.889      0.921      0.679

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      23.9G     0.5841     0.2681     0.8242        133       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.953      0.871      0.917      0.688

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      23.9G     0.5804     0.2653     0.8242        138       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.54it/s]
#                    all         75       1825      0.947      0.878      0.914      0.674

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      23.7G     0.5749     0.2624     0.8234        133       1280: 100% 309/309 [01:45<00:00,  2.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.60it/s]
#                    all         75       1825      0.923      0.893      0.919      0.683

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      23.9G     0.5686      0.259     0.8202        139       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.49it/s]
#                    all         75       1825      0.923      0.899      0.921      0.685

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      23.8G     0.5635      0.256     0.8188        139       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.50it/s]
#                    all         75       1825       0.94      0.887      0.925      0.687

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      23.9G     0.5582     0.2515      0.819        140       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.58it/s]
#                    all         75       1825      0.939      0.882       0.92      0.685

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      23.9G     0.5557     0.2509     0.8181        130       1280: 100% 309/309 [01:45<00:00,  2.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.59it/s]
#                    all         75       1825      0.938      0.901       0.93      0.694

# 50 epochs completed in 1.525 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 114.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 114.5MB

# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.90it/s]
#                    all         75       1825      0.939      0.901       0.93      0.695
#                   Ball         64        114      0.856      0.667      0.758      0.407
#             Goalkeeper         52         58      0.951      0.948      0.974      0.732
#                 Player         75       1488      0.979      0.987      0.994      0.849
#                Referee         75        165      0.969          1      0.994      0.792
# Speed: 0.5ms preprocess, 37.9ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## BLUR

# %%
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt'...
# 100% 109M/109M [00:01<00:00, 68.8MB/s]
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=yolo11x.pt, data=/content/updated-with-test-4/data.yaml, epochs=50, time=None, patience=100, batch=6, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 113MB/s]
# Overriding model.yaml nc=80 with nc=4

#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,878,396 parameters, 56,878,380 gradients, 195.5 GFLOPs

# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 361MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.93it/s]
#                    all         75       1825      0.948       0.89      0.926      0.697
#                   Ball         64        114       0.88       0.64      0.759      0.424
#             Goalkeeper         52         58      0.943      0.931      0.956      0.723
#                 Player         75       1488      0.985      0.987      0.994      0.848
#                Referee         75        165      0.983          1      0.995      0.791
# Speed: 0.5ms preprocess, 15.0ms inference, 0.0ms loss, 9.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## Light augments

# %%
# New https://pypi.org/project/ultralytics/8.3.108 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=yolo11x.pt, data=/content/updated-with-test-3/data.yaml, epochs=50, time=None, patience=100, batch=6, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train4
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744649696.374730   47488 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744649696.380201   47488 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=4

#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,878,396 parameters, 56,878,380 gradients, 195.5 GFLOPs

# Transferred 1009/1015 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train4', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/updated-with-test-3/train/labels... 1854 images, 0 backgrounds, 0 corrupt: 100% 1854/1854 [00:01<00:00, 1335.54it/s]
# train: New cache created: /content/updated-with-test-3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/updated-with-test-3/valid/labels... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<00:00, 969.48it/s]
# val: New cache created: /content/updated-with-test-3/valid/labels.cache
# Plotting labels to runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.000515625), 173 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 1280 train, 1280 val
# Using 8 dataloader workers
# Logging results to runs/detect/train4
# Starting training for 50 epochs...

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      24.6G     0.9295     0.7537     0.9064        162       1280: 100% 309/309 [01:53<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.08it/s]
#                    all         75       1825      0.792      0.691      0.749      0.487

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      29.2G      0.932     0.5679      0.906        205       1280: 100% 309/309 [01:48<00:00,  2.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.46it/s]
#                    all         75       1825      0.852      0.725      0.779      0.515

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      29.3G      1.006      0.569     0.9278        263       1280: 100% 309/309 [01:47<00:00,  2.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.24it/s]
#                    all         75       1825      0.825      0.684      0.767      0.504

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      29.4G     0.9931     0.6148     0.9211        171       1280: 100% 309/309 [01:47<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.49it/s]
#                    all         75       1825      0.931      0.718      0.808      0.549

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      29.5G     0.9168     0.5183     0.9018        243       1280: 100% 309/309 [01:47<00:00,  2.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.53it/s]
#                    all         75       1825       0.88      0.787      0.839      0.565

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      29.7G      0.877      0.469     0.8903        180       1280: 100% 309/309 [01:47<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.55it/s]
#                    all         75       1
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      35.8G     0.6398     0.3045     0.8256        113       1280: 100% 309/309 [01:46<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.54it/s]
#                    all         75       1825      0.933      0.876      0.905      0.672
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      24.6G     0.6119     0.2892     0.8315        147       1280: 100% 309/309 [01:47<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.49it/s]
#                    all         75       1825      0.929      0.869      0.915      0.667

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      28.1G     0.6059     0.2839      0.828        138       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.949      0.878      0.926      0.678

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      28.1G      0.603     0.2786     0.8274        142       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825      0.926      0.884      0.911      0.682

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      28.1G     0.5882     0.2713     0.8241        136       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.55it/s]
#                    all         75       1825      0.923      0.891      0.922       0.68

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      28.1G     0.5828      0.271     0.8235        138       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.51it/s]
#                    all         75       1825      0.945      0.897      0.928      0.679

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      28.1G     0.5787     0.2655     0.8225        139       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.59it/s]
#                    all         75       1825      0.949      0.894       0.93      0.686

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      28.1G     0.5695     0.2604     0.8183        143       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825      0.932      0.901       0.93      0.687

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      28.2G     0.5644     0.2587     0.8167        139       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.51it/s]
#                    all         75       1825      0.928      0.894      0.931      0.685

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      28.4G     0.5603     0.2544     0.8172        140       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.56it/s]
#                    all         75       1825      0.949      0.888      0.936      0.686

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      28.5G     0.5564     0.2527     0.8171        130       1280: 100% 309/309 [01:46<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.58it/s]
#                    all         75       1825      0.949      0.906      0.937      0.691

# 50 epochs completed in 1.536 hours.
# Optimizer stripped from runs/detect/train4/weights/last.pt, 114.5MB
# Optimizer stripped from runs/detect/train4/weights/best.pt, 114.5MB

# Validating runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.92it/s]
#                    all         75       1825      0.946      0.906      0.936      0.694
#                   Ball         64        114      0.868      0.695      0.777      0.407
#             Goalkeeper         52         58      0.947      0.948      0.978      0.729
#                 Player         75       1488      0.976      0.987      0.994      0.847
#                Referee         75        165      0.994      0.994      0.995      0.792
# Speed: 0.5ms preprocess, 15.1ms inference, 0.0ms loss, 9.3ms postprocess per image
# Results saved to runs/detect/train4
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt'...
# 100% 109M/109M [00:00<00:00, 304MB/s]
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=yolo11x.pt, data=/content/updated-with-test-2/data.yaml, epochs=50, time=None, patience=100, batch=6, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 13.6MB/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744638789.008043    1284 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744638789.013555    1284 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=4

#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,878,396 parameters, 56,878,380 gradients, 195.5 GFLOPs

# Transferred 1009/1015 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 63.9MB/s]
# AMP: checks passed ✅
# train: Scanning /content/updated-with-test-2/train/labels... 1854 images, 0 backgrounds, 0 corrupt: 100% 1854/1854 [00:01<00:00, 1416.63it/s]
# train: New cache created: /content/updated-with-test-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/updated-with-test-2/valid/labels... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<00:00, 1080.82it/s]
# val: New cache created: /content/updated-with-test-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.000515625), 173 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 1280 train, 1280 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      24.6G     0.9474     0.7639     0.9108        156       1280: 100% 309/309 [01:53<00:00,  2.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:02<00:00,  2.85it/s]
#                    all         75       1825      0.838      0.728      0.806       0.52

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      29.1G     0.9521     0.5635     0.9081        204       1280: 100% 309/309 [01:47<00:00,  2.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.51it/s]
#                    all         75       1825      0.849      0.737      0.778       0.51

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      29.3G      0.948     0.6146     0.9123        266       1280: 100% 309/309 [01:46<00:00,  2.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.45it/s]
#                    all         75       1825       0.77        0.7      0.766      0.496

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      29.4G     0.9207     0.5558     0.8993        173       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825       0.86      0.768      0.819      0.548

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      29.5G     0.9198     0.4955     0.8982        248       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.54it/s]
#                    all         75       1825       0.88      0.765      0.819      0.559

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      29.7G     0.8613     0.4645     0.8837        165       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.60it/s]
#                    all         75       1825       0.91      0.773       0.83      0.582

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      29.8G     0.8658     0.4577     0.8828        283       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.838      0.773      0.814      0.582

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      29.9G     0.8439     0.4431     0.8792        187       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.55it/s]
#                    all         75       1825      0.937      0.779      0.853      0.589

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50        30G     0.8244     0.4224     0.8685        214       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.60it/s]
#                    all         75       1825      0.924      0.804      0.859      0.624

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      30.2G     0.8055     0.4148     0.8678         96       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.897      0.845      0.879      0.619

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      30.3G     0.8081     0.4212     0.8712        239       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.52it/s]
#                    all         75       1825      0.907      0.822      0.879       0.63

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      30.4G     0.8353     0.4207     0.8734        187       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.60it/s]
#                    all         75       1825      0.919      0.842      0.885      0.628

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      30.6G     0.7765      0.398     0.8612        122       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.58it/s]
#                    all         75       1825      0.909      0.848      0.888      0.621

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      30.7G      0.782     0.3987     0.8606        171       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.61it/s]
#                    all         75       1825      0.911      0.828      0.877      0.619

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      30.8G     0.7739     0.3868     0.8617        176       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.56it/s]
#                    all         75       1825      0.885       0.82      0.865      0.632

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50        31G     0.7503     0.3766     0.8534        225       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.904      0.851      0.886      0.636

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      31.1G     0.7476     0.3777     0.8523        153       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.57it/s]
#                    all         75       1825      0.891      0.841      0.879      0.629

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      31.2G     0.7578     0.3805     0.8572        256       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.56it/s]
#                    all         75       1825      0.881      0.854      0.886      0.642

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      31.4G     0.7428     0.3707     0.8522        290       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.55it/s]
#                    all         75       1825      0.927      0.852      0.886      0.626

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      31.5G     0.7387     0.3644     0.8477        131       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.60it/s]
#                    all         75       1825      0.893      0.864      0.902       0.66

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      31.6G     0.7343     0.3617     0.8472        242       1280: 100% 309/309 [01:46<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.55it/s]
#                    all         75       1825      0.894      0.864      0.903      0.645

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.53it/s]
#                    all         75       1825      0.933      0.896      0.934      0.699

# 50 epochs completed in 1.533 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 114.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 114.5MB

# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.87it/s]
#                    all         75       1825      0.933      0.896      0.934      0.699
#                   Ball         64        114      0.851      0.658       0.78      0.418
#             Goalkeeper         52         58      0.938      0.948      0.969      0.739
#                 Player         75       1488      0.979      0.986      0.994      0.847
#                Referee         75        165      0.963      0.994      0.995      0.792
# Speed: 0.8ms preprocess, 19.8ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## No Augmentations

# %%
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: task=detect, mode=train, model=yolo11x.pt, data=/content/updated-with-test-1/data.yaml, epochs=50, time=None, patience=100, batch=6, imgsz=1280, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744646847.837126   35212 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744646847.842890   35212 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=4

#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3150172  ultralytics.nn.modules.head.Detect           [4, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,878,396 parameters, 56,878,380 gradients, 195.5 GFLOPs

# Transferred 1009/1015 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/updated-with-test-1/train/labels.cache... 618 images, 0 backgrounds, 0 corrupt: 100% 618/618 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/updated-with-test-1/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.000515625), 173 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 1280 train, 1280 val
# Using 8 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      24.4G     0.9896      1.071     0.9322        179       1280: 100% 103/103 [00:39<00:00,  2.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:01<00:00,  4.05it/s]
#                    all         75       1825       0.61       0.61      0.558       0.36

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      28.8G      1.028     0.7247     0.9433        250       1280: 100% 103/103 [00:36<00:00,  2.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:02<00:00,  3.16it/s]
#                    all         75       1825      0.633      0.544      0.542      0.392

#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.92it/s]
#                    all         75       1825      0.922      0.834      0.891      0.659
#                   Ball         64        114      0.824      0.493      0.636      0.339
#             Goalkeeper         52         58      0.913      0.879      0.946      0.695
#                 Player         75       1488      0.982      0.982      0.993      0.834
#                Referee         75        165      0.969      0.982      0.991      0.768
# Speed: 0.5ms preprocess, 38.6ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## Evaluation

# %%
model = YOLO('/content/runs/detect/train3/weights/best.pt')

# %%
results = model.val(data="/content/updated-with-test-4/data.yaml")

# %%
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2645.5±1843.5 MB/s, size: 172.8 KB)

# val: Scanning /content/updated-with-test-4/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100%|██████████| 75/75 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]

#                    all         75       1825      0.944      0.902      0.933      0.716
#                   Ball         64        114      0.875      0.674      0.768      0.441
#             Goalkeeper         52         58       0.95      0.948      0.974      0.758
#                 Player         75       1488      0.981      0.988      0.994      0.863
#                Referee         75        165      0.969          1      0.993      0.805
# Speed: 10.6ms preprocess, 22.1ms inference, 0.0ms loss, 17.0ms postprocess per image
# Results saved to runs/detect/val4

# %% [markdown]
# ##Blur

# %%
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2676.7±1310.5 MB/s, size: 157.2 KB)

# val: Scanning /content/updated-with-test-4/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100%|██████████| 75/75 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]

#                    all         75       1825      0.954      0.894      0.932      0.709
#                   Ball         64        114      0.891      0.642      0.769      0.441
#             Goalkeeper         52         58      0.959      0.948       0.97      0.737
#                 Player         75       1488      0.985      0.987      0.994      0.861
#                Referee         75        165      0.983          1      0.995      0.798
# Speed: 9.8ms preprocess, 22.7ms inference, 0.0ms loss, 17.0ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# ## Light augments

# %%
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,831,644 parameters, 0 gradients, 194.4 GFLOPs

# val: Scanning /content/updated-with-test-1/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100%|██████████| 75/75 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]

#                    all         75       1825      0.951      0.906      0.939      0.711
#                   Ball         64        114      0.888      0.695      0.788      0.431
#             Goalkeeper         52         58      0.947      0.948      0.978      0.746
#                 Player         75       1488      0.977      0.987      0.994      0.863
#                Referee         75        165      0.994      0.994      0.995      0.802
# Speed: 10.3ms preprocess, 23.5ms inference, 0.3ms loss, 14.6ms postprocess per image
# Results saved to runs/detect/val9

# %% [markdown]
# ## Augments

# %%
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)

# val: Scanning /content/updated-with-test-2/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100%|██████████| 75/75 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]

#                    all         75       1825      0.938      0.899      0.934      0.715
#                   Ball         64        114      0.873      0.667      0.778      0.438
#             Goalkeeper         52         58      0.938      0.948      0.969      0.759
#                 Player         75       1488      0.981      0.986      0.994      0.862
#                Referee         75        165      0.963      0.994      0.995        0.8
# Speed: 10.4ms preprocess, 22.8ms inference, 0.0ms loss, 14.6ms postprocess per image
# Results saved to runs/detect/val5

# %%
results = model.val(split="test", data="/content/updated-with-test-4/data.yaml")

# %%
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3663.9±957.5 MB/s, size: 191.6 KB)

# val: Scanning /content/updated-with-test-4/test/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.06it/s]

#                    all        100       2487      0.884      0.798      0.822      0.606
#                   Ball         97        185       0.84      0.303      0.402      0.166
#             Goalkeeper         73         79      0.766      0.937       0.94      0.746
#                 Player        100       1998      0.995      0.989      0.994      0.814
#                Referee        100        225      0.935      0.962      0.954      0.699
# Speed: 7.2ms preprocess, 22.2ms inference, 0.0ms loss, 12.8ms postprocess per image
# Results saved to runs/detect/val5

# %% [markdown]
# ## BlUR AUGS

# %%
# Ultralytics 8.3.112 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3288.5±909.4 MB/s, size: 184.7 KB)

# val: Scanning /content/updated-with-test-4/test/labels... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<00:00, 1437.83it/s]

# val: New cache created: /content/updated-with-test-4/test/labels.cache


#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.10it/s]

#                    all        100       2487        0.9      0.809      0.829      0.604
#                   Ball         97        185      0.877      0.335      0.442      0.182
#             Goalkeeper         73         79      0.816      0.949      0.921       0.72
#                 Player        100       1998      0.989      0.992      0.994      0.815
#                Referee        100        225       0.92       0.96      0.958      0.698
# Speed: 7.8ms preprocess, 22.2ms inference, 0.0ms loss, 11.6ms postprocess per image
# Results saved to runs/detect/val3

# %% [markdown]
# ## Light augs

# %%
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)

# val: Scanning /content/updated-with-test-3/test/labels... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<00:00, 1367.58it/s]

# val: New cache created: /content/updated-with-test-3/test/labels.cache


#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.07it/s]

#                    all        100       2487      0.933       0.81      0.844      0.615
#                   Ball         97        185      0.912      0.341      0.468      0.178
#             Goalkeeper         73         79      0.894      0.949      0.959      0.767
#                 Player        100       1998      0.992      0.993      0.994      0.815
#                Referee        100        225      0.935      0.955      0.954      0.701
# Speed: 8.4ms preprocess, 22.5ms inference, 0.0ms loss, 11.1ms postprocess per image
# Results saved to runs/detect/val10

# %% [markdown]
# ## No aug

# %%
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)

# val: Scanning /content/updated-with-test-1/test/labels... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<00:00, 1279.36it/s]

# val: New cache created: /content/updated-with-test-1/test/labels.cache


#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.02it/s]

#                    all        100       2487      0.929      0.801      0.835      0.613
#                   Ball         97        185       0.95      0.306      0.436       0.18
#             Goalkeeper         73         79      0.845      0.962      0.944      0.749
#                 Player        100       1998      0.987       0.99      0.994      0.809
#                Referee        100        225      0.934      0.947      0.966      0.715
# Speed: 7.8ms preprocess, 22.0ms inference, 0.0ms loss, 1

# %%
# val: Scanning /content/updated-with-test-2/test/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.10it/s]

#                    all        100       2487      0.856      0.802      0.813        0.6
#                   Ball         97        185      0.739      0.335      0.386       0.16
#             Goalkeeper         73         79      0.779      0.924      0.939      0.733
#                 Player        100       1998       0.99      0.993      0.993      0.813
#                Referee        100        225      0.917      0.956      0.934      0.695
# Speed: 7.9ms preprocess, 22.1ms inference, 0.0ms loss, 10.0ms postprocess per image
# Results saved to runs/detect/val6

# %%
# !zip -r /content/val_hsv_aug.zip /content/runs/detect/val5

# %%
from ultralytics import YOLO


# !yolo task=pose mode=train model=yolov8m-pose.pt data={dataset.location}/data.yaml batch=6 epochs=200 imgsz=640 mosaic=0.0 plots=True

# %%
project.version(dataset.version).deploy(model_type="yolo11x", model_path="runs/detect/train5/")
